# %%
import pandas as pd

# %%
df = pd.read_csv('data/Share of Organic Agricultural land.csv')
df
# Out:
#      Domain Code    Domain  Area Code (M49)         Area  Element Code  \
# 0             RL  Land Use                4  Afghanistan          5110
# 1             RL  Land Use              882        Samoa          7208
# 2             RL  Land Use                4  Afghanistan          5110
# 3             RL  Land Use              882        Samoa          7208
# 4             RL  Land Use                4  Afghanistan          5110
# ...          ...       ...              ...          ...           ...
# 1928          RL  Land Use              716     Zimbabwe          7208
# 1929          RL  Land Use              716     Zimbabwe          5110
# 1930          RL  Land Use              716     Zimbabwe          5110
# 1931          RL  Land Use              716     Zimbabwe          5110
# 1932          RL  Land Use              716     Zimbabwe          5110
#
#                          Element  Item Code  \
# 0                           Area       6671
# 1     Share in Agricultural land       6671
# 2                           Area       6671
# 3     Share in Agricultural land       6671
# 4                           Area       6671
# ...                          ...        ...
# 1928  Share in Agricultural land       6671
# 1929                        Area       6672
# 1930                        Area       6672
# 1931                        Area       6672
# 1932                        Area       6672
#
#                                        Item  Year Code  Year     Unit  \
# 0     Agriculture area under organic agric.       2020  2020  1000 ha
# 1     Agriculture area under organic agric.       2022  2022        %
# 2     Agriculture area under organic agric.       2021  2021  1000 ha
# 3     Agriculture area under organic agric.       2023  2023        %
# 4     Agriculture area under organic agric.       2022  2022  1000 ha
# ...                                     ...        ...   ...      ...
# 1928  Agriculture area under organic agric.       2023  2023        %
# 1929     Agriculture area certified organic       2020  2020  1000 ha
# 1930     Agriculture area certified organic       2021  2021  1000 ha
# 1931     Agriculture area certified organic       2022  2022  1000 ha
# 1932     Agriculture area certified organic       2023  2023  1000 ha
#
#         Value Flag                     Flag Description
# 0      0.0977    I  Value imputed by a receiving agency
# 1     95.4700    E                      Estimated value
# 2      0.0977    I  Value imputed by a receiving agency
# 3     84.5900    E                      Estimated value
# 4      0.0977    I  Value imputed by a receiving agency
# ...       ...  ...                                  ...
# 1928   0.0000    E                      Estimated value
# 1929   1.0400    I  Value imputed by a receiving agency
# 1930   1.0199    I  Value imputed by a receiving agency
# 1931   1.0199    I  Value imputed by a receiving agency
# 1932   0.3339    I  Value imputed by a receiving agency
#
# [1933 rows x 14 columns]

# %% [markdown]
# ### Normalization Step: Add ISO-alpha3 Code

# %%
# --- Normalization: Add ISO-alpha3 column ---

# 1. Load UNSD Methodology for mapping
try:
    unsd_df = pd.read_csv('data/UNSD — Methodology.csv', sep=';')
except FileNotFoundError:
    unsd_df = pd.read_csv('../data/UNSD — Methodology.csv', sep=';')

# 2. Create mappings
unsd_df['Country or Area'] = unsd_df['Country or Area'].astype(str).str.strip()
name_to_iso3 = unsd_df.set_index('Country or Area')['ISO-alpha3 Code'].to_dict()

m49_to_iso3 = {}
for idx, row in unsd_df.iterrows():
    try:
        # Handle potential non-numeric or NaN M49 codes
        m49_code = int(row['M49 Code'])
        m49_to_iso3[m49_code] = row['ISO-alpha3 Code']
    except (ValueError, TypeError):
        continue

# 3. Apply mapping
print("Applying ISO-alpha3 normalization...")
if 'Area Code (M49)' in df.columns:
    def get_iso(val):
        try:
            return m49_to_iso3.get(int(val), None)
        except:
            return None
    df['iso_alpha3'] = df['Area Code (M49)'].apply(get_iso)
    print("  Mapped M49 codes to 'iso_alpha3'.")
else:
    print("  Warning: Source column 'Area Code (M49)' not found.")

# Check results
missing_iso = df['iso_alpha3'].isna().sum()
if missing_iso > 0:
    print(f"  Warning: {missing_iso} rows have missing ISO-alpha3 codes.")
    print(df[df['iso_alpha3'].isna()][['Area Code (M49)']].head())

# %%
uniques = df.nunique()
cols_to_drop = uniques[uniques <= 1].index
df = df.drop(columns=cols_to_drop)
df
# Out:
#       Area Code (M49)         Area  Element Code                     Element  \
# 0                   4  Afghanistan          5110                        Area
# 1                 882        Samoa          7208  Share in Agricultural land
# 2                   4  Afghanistan          5110                        Area
# 3                 882        Samoa          7208  Share in Agricultural land
# 4                   4  Afghanistan          5110                        Area
# ...               ...          ...           ...                         ...
# 1928              716     Zimbabwe          7208  Share in Agricultural land
# 1929              716     Zimbabwe          5110                        Area
# 1930              716     Zimbabwe          5110                        Area
# 1931              716     Zimbabwe          5110                        Area
# 1932              716     Zimbabwe          5110                        Area
#
#       Item Code                                   Item  Year Code  Year  \
# 0          6671  Agriculture area under organic agric.       2020  2020
# 1          6671  Agriculture area under organic agric.       2022  2022
# 2          6671  Agriculture area under organic agric.       2021  2021
# 3          6671  Agriculture area under organic agric.       2023  2023
# 4          6671  Agriculture area under organic agric.       2022  2022
# ...         ...                                    ...        ...   ...
# 1928       6671  Agriculture area under organic agric.       2023  2023
# 1929       6672     Agriculture area certified organic       2020  2020
# 1930       6672     Agriculture area certified organic       2021  2021
# 1931       6672     Agriculture area certified organic       2022  2022
# 1932       6672     Agriculture area certified organic       2023  2023
#
#          Unit    Value Flag                     Flag Description
# 0     1000 ha   0.0977    I  Value imputed by a receiving agency
# 1           %  95.4700    E                      Estimated value
# 2     1000 ha   0.0977    I  Value imputed by a receiving agency
# 3           %  84.5900    E                      Estimated value
# 4     1000 ha   0.0977    I  Value imputed by a receiving agency
# ...       ...      ...  ...                                  ...
# 1928        %   0.0000    E                      Estimated value
# 1929  1000 ha   1.0400    I  Value imputed by a receiving agency
# 1930  1000 ha   1.0199    I  Value imputed by a receiving agency
# 1931  1000 ha   1.0199    I  Value imputed by a receiving agency
# 1932  1000 ha   0.3339    I  Value imputed by a receiving agency
#
# [1933 rows x 12 columns]

# %%
df = df.drop(columns=['Element Code','Item Code','Year Code','Flag', 'Flag Description'])
df
# Out:
#       Area Code (M49)         Area                     Element  \
# 0                   4  Afghanistan                        Area
# 1                 882        Samoa  Share in Agricultural land
# 2                   4  Afghanistan                        Area
# 3                 882        Samoa  Share in Agricultural land
# 4                   4  Afghanistan                        Area
# ...               ...          ...                         ...
# 1928              716     Zimbabwe  Share in Agricultural land
# 1929              716     Zimbabwe                        Area
# 1930              716     Zimbabwe                        Area
# 1931              716     Zimbabwe                        Area
# 1932              716     Zimbabwe                        Area
#
#                                        Item  Year     Unit    Value
# 0     Agriculture area under organic agric.  2020  1000 ha   0.0977
# 1     Agriculture area under organic agric.  2022        %  95.4700
# 2     Agriculture area under organic agric.  2021  1000 ha   0.0977
# 3     Agriculture area under organic agric.  2023        %  84.5900
# 4     Agriculture area under organic agric.  2022  1000 ha   0.0977
# ...                                     ...   ...      ...      ...
# 1928  Agriculture area under organic agric.  2023        %   0.0000
# 1929     Agriculture area certified organic  2020  1000 ha   1.0400
# 1930     Agriculture area certified organic  2021  1000 ha   1.0199
# 1931     Agriculture area certified organic  2022  1000 ha   1.0199
# 1932     Agriculture area certified organic  2023  1000 ha   0.3339
#
# [1933 rows x 7 columns]

# %%
df = df[df['Element'] == 'Share in Agricultural land'].reset_index(drop=True)
df
# Out:
#      Area Code (M49)           Area                     Element  \
# 0                882          Samoa  Share in Agricultural land
# 1                882          Samoa  Share in Agricultural land
# 2                882          Samoa  Share in Agricultural land
# 3                882          Samoa  Share in Agricultural land
# 4                438  Liechtenstein  Share in Agricultural land
# ..               ...            ...                         ...
# 669              512           Oman  Share in Agricultural land
# 670              512           Oman  Share in Agricultural land
# 671              512           Oman  Share in Agricultural land
# 672              894         Zambia  Share in Agricultural land
# 673              716       Zimbabwe  Share in Agricultural land
#
#                                       Item  Year Unit  Value
# 0    Agriculture area under organic agric.  2022    %  95.47
# 1    Agriculture area under organic agric.  2023    %  84.59
# 2    Agriculture area under organic agric.  2020    %  82.96
# 3    Agriculture area under organic agric.  2021    %  82.96
# 4    Agriculture area under organic agric.  2023    %  31.18
# ..                                     ...   ...  ...    ...
# 669  Agriculture area under organic agric.  2021    %   0.00
# 670  Agriculture area under organic agric.  2022    %   0.00
# 671  Agriculture area under organic agric.  2023    %   0.00
# 672  Agriculture area under organic agric.  2020    %   0.00
# 673  Agriculture area under organic agric.  2023    %   0.00
#
# [674 rows x 7 columns]

# %%
uniques = df.nunique()
cols_to_drop = uniques[uniques <= 1].index
df = df.drop(columns=cols_to_drop)
df
# Out:
#      Area Code (M49)           Area  Year  Value
# 0                882          Samoa  2022  95.47
# 1                882          Samoa  2023  84.59
# 2                882          Samoa  2020  82.96
# 3                882          Samoa  2021  82.96
# 4                438  Liechtenstein  2023  31.18
# ..               ...            ...   ...    ...
# 669              512           Oman  2021   0.00
# 670              512           Oman  2022   0.00
# 671              512           Oman  2023   0.00
# 672              894         Zambia  2020   0.00
# 673              716       Zimbabwe  2023   0.00
#
# [674 rows x 4 columns]

# %%
df.rename(columns={'Value': 'Share of Organic Agricultural land (%)'}, inplace=True)
df
# Out:
#      Area Code (M49)           Area  Year  \
# 0                882          Samoa  2022
# 1                882          Samoa  2023
# 2                882          Samoa  2020
# 3                882          Samoa  2021
# 4                438  Liechtenstein  2023
# ..               ...            ...   ...
# 669              512           Oman  2021
# 670              512           Oman  2022
# 671              512           Oman  2023
# 672              894         Zambia  2020
# 673              716       Zimbabwe  2023
#
#      Share of Organic Agricultural land (%)
# 0                                     95.47
# 1                                     84.59
# 2                                     82.96
# 3                                     82.96
# 4                                     31.18
# ..                                      ...
# 669                                    0.00
# 670                                    0.00
# 671                                    0.00
# 672                                    0.00
# 673                                    0.00
#
# [674 rows x 4 columns]

# %%
df = df.sort_values(by='Area')
df
# Out:
#      Area Code (M49)         Area  Year  \
# 643                4  Afghanistan  2020
# 646                4  Afghanistan  2023
# 645                4  Afghanistan  2022
# 644                4  Afghanistan  2021
# 552                8      Albania  2022
# ..               ...          ...   ...
# 672              894       Zambia  2020
# 641              716     Zimbabwe  2021
# 640              716     Zimbabwe  2020
# 642              716     Zimbabwe  2022
# 673              716     Zimbabwe  2023
#
#      Share of Organic Agricultural land (%)
# 643                                    0.00
# 646                                    0.00
# 645                                    0.00
# 644                                    0.00
# 552                                    0.06
# ..                                      ...
# 672                                    0.00
# 641                                    0.01
# 640                                    0.01
# 642                                    0.01
# 673                                    0.00
#
# [674 rows x 4 columns]

# %%
df.rename(columns={'Area': 'Country Name'}, inplace=True)
df
# Out:
#      Area Code (M49) Country Name  Year  \
# 643                4  Afghanistan  2020
# 646                4  Afghanistan  2023
# 645                4  Afghanistan  2022
# 644                4  Afghanistan  2021
# 552                8      Albania  2022
# ..               ...          ...   ...
# 672              894       Zambia  2020
# 641              716     Zimbabwe  2021
# 640              716     Zimbabwe  2020
# 642              716     Zimbabwe  2022
# 673              716     Zimbabwe  2023
#
#      Share of Organic Agricultural land (%)
# 643                                    0.00
# 646                                    0.00
# 645                                    0.00
# 644                                    0.00
# 552                                    0.06
# ..                                      ...
# 672                                    0.00
# 641                                    0.01
# 640                                    0.01
# 642                                    0.01
# 673                                    0.00
#
# [674 rows x 4 columns]
