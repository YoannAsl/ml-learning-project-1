# %%
import pandas as pd

# %%
df = pd.read_csv('data/GDP per Capita in USD - GDP per capita.csv')
df
# Out:
#       REF_AREA               REF_AREA_LABEL               INDICATOR_LABEL  \
# 0          AFE  Africa Eastern and Southern  GDP per capita (current US$)
# 1          AFW   Africa Western and Central  GDP per capita (current US$)
# 2          CSS       Caribbean small states  GDP per capita (current US$)
# 3          EAR   Early-demographic dividend  GDP per capita (current US$)
# 4          EAS          East Asia & Pacific  GDP per capita (current US$)
# ...        ...                          ...                           ...
# 14536      SOM                      Somalia  GDP per capita (current US$)
# 14537      MDG                   Madagascar  GDP per capita (current US$)
# 14538      CAF     Central African Republic  GDP per capita (current US$)
# 14539      MWI                       Malawi  GDP per capita (current US$)
# 14540      BDI                      Burundi  GDP per capita (current US$)
#
#        TIME_PERIOD   OBS_VALUE                    COMMENT_TS  UNIT_MULT  \
# 0             1960  186.121835  GDP per capita (current US$)          0
# 1             1960  121.939925  GDP per capita (current US$)          0
# 2             1960  455.490442  GDP per capita (current US$)          0
# 3             1960  149.209963  GDP per capita (current US$)          0
# 4             1960  150.820305  GDP per capita (current US$)          0
# ...            ...         ...                           ...        ...
# 14536         2024  636.983478  GDP per capita (current US$)          0
# 14537         2024  544.997303  GDP per capita (current US$)          0
# 14538         2024  516.170424  GDP per capita (current US$)          0
# 14539         2024  508.371273  GDP per capita (current US$)          0
# 14540         2024  153.930218  GDP per capita (current US$)          0
#
#       UNIT_MULT_LABEL DATA_SOURCE                   DATA_SOURCE_LABEL  ...  \
# 0               Units      WB_WDI  World Development Indicators (WDI)  ...
# 1               Units      WB_WDI  World Development Indicators (WDI)  ...
# 2               Units      WB_WDI  World Development Indicators (WDI)  ...
# 3               Units      WB_WDI  World Development Indicators (WDI)  ...
# 4               Units      WB_WDI  World Development Indicators (WDI)  ...
# ...               ...         ...                                 ...  ...
# 14536           Units      WB_WDI  World Development Indicators (WDI)  ...
# 14537           Units      WB_WDI  World Development Indicators (WDI)  ...
# 14538           Units      WB_WDI  World Development Indicators (WDI)  ...
# 14539           Units      WB_WDI  World Development Indicators (WDI)  ...
# 14540           Units      WB_WDI  World Development Indicators (WDI)  ...
#
#       UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL COMMENT_OBS  OBS_STATUS  \
# 0            Currency         P1Y            Annual         NaN           A
# 1            Currency         P1Y            Annual         NaN           A
# 2            Currency         P1Y            Annual         NaN           A
# 3            Currency         P1Y            Annual         NaN           A
# 4            Currency         P1Y            Annual         NaN           A
# ...               ...         ...               ...         ...         ...
# 14536        Currency         P1Y            Annual         NaN           A
# 14537        Currency         P1Y            Annual         NaN           A
# 14538        Currency         P1Y            Annual         NaN           A
# 14539        Currency         P1Y            Annual         NaN           A
# 14540        Currency         P1Y            Annual         NaN           A
#
#       OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL Column 1  Column 2
# 0         Normal value       PU         Public      NaN       NaN
# 1         Normal value       PU         Public      NaN       NaN
# 2         Normal value       PU         Public      NaN       NaN
# 3         Normal value       PU         Public      NaN       NaN
# 4         Normal value       PU         Public      NaN       NaN
# ...                ...      ...            ...      ...       ...
# 14536     Normal value       PU         Public      NaN       NaN
# 14537     Normal value       PU         Public      NaN       NaN
# 14538     Normal value       PU         Public      NaN       NaN
# 14539     Normal value       PU         Public      NaN       NaN
# 14540     Normal value       PU         Public      NaN       NaN
#
# [14541 rows x 21 columns]

# %% [markdown]
# ### Normalization Step: Add ISO-alpha3 Code

# %%
# --- Normalization: Add ISO-alpha3 column ---

# 1. Load UNSD Methodology for mapping
try:
    unsd_df = pd.read_csv('data/UNSD — Methodology.csv', sep=';')
except FileNotFoundError:
    unsd_df = pd.read_csv('../data/UNSD — Methodology.csv', sep=';')

# 2. Create mappings
unsd_df['Country or Area'] = unsd_df['Country or Area'].astype(str).str.strip()
name_to_iso3 = unsd_df.set_index('Country or Area')['ISO-alpha3 Code'].to_dict()

m49_to_iso3 = {}
for idx, row in unsd_df.iterrows():
    try:
        # Handle potential non-numeric or NaN M49 codes
        m49_code = int(row['M49 Code'])
        m49_to_iso3[m49_code] = row['ISO-alpha3 Code']
    except (ValueError, TypeError):
        continue

# 3. Apply mapping
print("Applying ISO-alpha3 normalization...")
if 'REF_AREA' in df.columns:
    df['iso_alpha3'] = df['REF_AREA']
    print("  Column copied to 'iso_alpha3'.")
else:
    print("  Warning: Source column 'REF_AREA' not found.")

# Check results
missing_iso = df['iso_alpha3'].isna().sum()
if missing_iso > 0:
    print(f"  Warning: {missing_iso} rows have missing ISO-alpha3 codes.")
    print(df[df['iso_alpha3'].isna()][['REF_AREA']].head())

# %%
uniques = df.nunique()
cols_to_drop = uniques[uniques <= 1].index
df_filtered = df.drop(columns=cols_to_drop)
df = df_filtered
df
# Out:
#       REF_AREA               REF_AREA_LABEL  TIME_PERIOD   OBS_VALUE
# 0          AFE  Africa Eastern and Southern         1960  186.121835
# 1          AFW   Africa Western and Central         1960  121.939925
# 2          CSS       Caribbean small states         1960  455.490442
# 3          EAR   Early-demographic dividend         1960  149.209963
# 4          EAS          East Asia & Pacific         1960  150.820305
# ...        ...                          ...          ...         ...
# 14536      SOM                      Somalia         2024  636.983478
# 14537      MDG                   Madagascar         2024  544.997303
# 14538      CAF     Central African Republic         2024  516.170424
# 14539      MWI                       Malawi         2024  508.371273
# 14540      BDI                      Burundi         2024  153.930218
#
# [14541 rows x 4 columns]

# %%
column_to_check = 'TIME_PERIOD'
threshold_number = 2015
rows_to_keep_condition = df[column_to_check] >= threshold_number
df_result = df[rows_to_keep_condition].reset_index(drop=True)
df = df_result
df.rename(columns={'OBS_VALUE': 'GDP per capita (current US$)'}, inplace=True)
df
# Out:
#      REF_AREA                   REF_AREA_LABEL  TIME_PERIOD  \
# 0         AFE      Africa Eastern and Southern         2015
# 1         AFW       Africa Western and Central         2015
# 2         ARB                       Arab World         2015
# 3         CSS           Caribbean small states         2015
# 4         CEB  Central Electricity Board (CEB)         2015
# ...       ...                              ...          ...
# 2535      SOM                          Somalia         2024
# 2536      MDG                       Madagascar         2024
# 2537      CAF         Central African Republic         2024
# 2538      MWI                           Malawi         2024
# 2539      BDI                          Burundi         2024
#
#       GDP per capita (current US$)
# 0                      1479.615260
# 1                      1860.727694
# 2                      6262.041685
# 3                     14402.472580
# 4                     12596.947510
# ...                            ...
# 2535                    636.983478
# 2536                    544.997303
# 2537                    516.170424
# 2538                    508.371273
# 2539                    153.930218
#
# [2540 rows x 4 columns]

# %%
df.rename(columns={'REF_AREA': 'Country Code'}, inplace=True)
df.rename(columns={'REF_AREA_LABEL': 'Country Name'}, inplace=True)
df.rename(columns={'TIME_PERIOD': 'Year'}, inplace=True)
df
# Out:
#      Country Code                     Country Name  Year  \
# 0             AFE      Africa Eastern and Southern  2015
# 1             AFW       Africa Western and Central  2015
# 2             ARB                       Arab World  2015
# 3             CSS           Caribbean small states  2015
# 4             CEB  Central Electricity Board (CEB)  2015
# ...           ...                              ...   ...
# 2535          SOM                          Somalia  2024
# 2536          MDG                       Madagascar  2024
# 2537          CAF         Central African Republic  2024
# 2538          MWI                           Malawi  2024
# 2539          BDI                          Burundi  2024
#
#       GDP per capita (current US$)
# 0                      1479.615260
# 1                      1860.727694
# 2                      6262.041685
# 3                     14402.472580
# 4                     12596.947510
# ...                            ...
# 2535                    636.983478
# 2536                    544.997303
# 2537                    516.170424
# 2538                    508.371273
# 2539                    153.930218
#
# [2540 rows x 4 columns]
