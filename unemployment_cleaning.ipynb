# %%
import pandas as pd

# %%
df = pd.read_csv('data/Unemployment 2015-2024.csv')
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# ..                                                 ...             ...
# 261  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 264  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 265  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#           2015       2016       2017       2018       2019       2020  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1     7.036357   7.194666   7.346331   7.360513   7.584419   8.191395
# 2     9.052000  10.133000  11.184000  11.196000  11.185000  11.710000
# 3     4.164467   4.157574   4.274196   4.323631   4.395271   4.852393
# 4    16.490000  16.575000  16.610000  16.594000  16.497000  16.690000
# ..         ...        ...        ...        ...        ...        ...
# 261        NaN        NaN        NaN        NaN        NaN        NaN
# 262  17.900000  18.416000  18.603000  17.584000  17.202000  17.953000
# 263  25.149000  26.536000  27.035000  26.906000  28.468000  29.217000
# 264   5.942000   5.239000   4.529000   5.033000   5.542000   6.033000
# 265   5.377000   5.886000   6.344000   6.793000   7.373000   8.621000
#
#           2021       2022       2023       2024
# 0          NaN        NaN        NaN        NaN
# 1     8.577385   7.985202   7.806365   7.772654
# 2    11.994000  14.100000  13.991000  13.295000
# 3     4.736732   3.658573   3.277245   3.218313
# 4    15.799000  14.602000  14.537000  14.464000
# ..         ...        ...        ...        ...
# 261        NaN        NaN        NaN        NaN
# 262  18.287000  17.363000  17.091000  17.086000
# 263  34.007000  33.268000  32.098000  33.168000
# 264   5.199000   5.995000   5.905000   5.961000
# 265   9.540000  10.087000   8.759000   8.554000
#
# [266 rows x 14 columns]

# %%
uniques = df.nunique()
cols_to_drop = uniques[uniques <= 1].index
df_filtered = df.drop(columns=cols_to_drop)
df = df_filtered
df
# Out:
#                     Country Name Country Code       2015       2016  \
# 0                          Aruba          ABW        NaN        NaN
# 1    Africa Eastern and Southern          AFE   7.036357   7.194666
# 2                    Afghanistan          AFG   9.052000  10.133000
# 3     Africa Western and Central          AFW   4.164467   4.157574
# 4                         Angola          AGO  16.490000  16.575000
# ..                           ...          ...        ...        ...
# 261                       Kosovo          XKX        NaN        NaN
# 262                  Yemen, Rep.          YEM  17.900000  18.416000
# 263                 South Africa          ZAF  25.149000  26.536000
# 264                       Zambia          ZMB   5.942000   5.239000
# 265                     Zimbabwe          ZWE   5.377000   5.886000
#
#           2017       2018       2019       2020       2021       2022  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1     7.346331   7.360513   7.584419   8.191395   8.577385   7.985202
# 2    11.184000  11.196000  11.185000  11.710000  11.994000  14.100000
# 3     4.274196   4.323631   4.395271   4.852393   4.736732   3.658573
# 4    16.610000  16.594000  16.497000  16.690000  15.799000  14.602000
# ..         ...        ...        ...        ...        ...        ...
# 261        NaN        NaN        NaN        NaN        NaN        NaN
# 262  18.603000  17.584000  17.202000  17.953000  18.287000  17.363000
# 263  27.035000  26.906000  28.468000  29.217000  34.007000  33.268000
# 264   4.529000   5.033000   5.542000   6.033000   5.199000   5.995000
# 265   6.344000   6.793000   7.373000   8.621000   9.540000  10.087000
#
#           2023       2024
# 0          NaN        NaN
# 1     7.806365   7.772654
# 2    13.991000  13.295000
# 3     3.277245   3.218313
# 4    14.537000  14.464000
# ..         ...        ...
# 261        NaN        NaN
# 262  17.091000  17.086000
# 263  32.098000  33.168000
# 264   5.905000   5.961000
# 265   8.759000   8.554000
#
# [266 rows x 12 columns]

# %%
id_vars = ['Country Name', 'Country Code']
value_vars = [col for col in df.columns if col not in id_vars]

df_melted = df.melt(
    id_vars=id_vars,
    value_vars=value_vars,
    var_name='Year',      
    value_name='Unemployment (% of total labor force)'    
)
df_melted['Year'] = df_melted['Year'].astype(int)
df = df_melted
df
# Out:
#                      Country Name Country Code  Year  \
# 0                           Aruba          ABW  2015
# 1     Africa Eastern and Southern          AFE  2015
# 2                     Afghanistan          AFG  2015
# 3      Africa Western and Central          AFW  2015
# 4                          Angola          AGO  2015
# ...                           ...          ...   ...
# 2655                       Kosovo          XKX  2024
# 2656                  Yemen, Rep.          YEM  2024
# 2657                 South Africa          ZAF  2024
# 2658                       Zambia          ZMB  2024
# 2659                     Zimbabwe          ZWE  2024
#
#       Unemployment (% of total labor force)
# 0                                       NaN
# 1                                  7.036357
# 2                                  9.052000
# 3                                  4.164467
# 4                                 16.490000
# ...                                     ...
# 2655                                    NaN
# 2656                              17.086000
# 2657                              33.168000
# 2658                               5.961000
# 2659                               8.554000
#
# [2660 rows x 4 columns]

# %%
# df.dropna().reset_index(drop=True)
